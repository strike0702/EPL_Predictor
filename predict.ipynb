# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv",index_col=0)

# %%
matches.head(10)
# Out:
#           Date   Time            Comp         Round  Day Venue Result  GF  GA  \
# 1   2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away      W   2   0
# 2   2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W   4   0
# 3   2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D   3   3
# 4   2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W   4   2
# 5   2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W   6   0
# 6   2022-09-03  17:30  Premier League   Matchweek 6  Sat  Away      D   1   1
# 9   2022-09-17  12:30  Premier League   Matchweek 8  Sat  Away      W   3   0
# 10  2022-10-02  14:00  Premier League   Matchweek 9  Sun  Home      W   6   3
# 12  2022-10-08  15:00  Premier League  Matchweek 10  Sat  Home      W   4   0
# 14  2022-10-16  16:30  Premier League  Matchweek 11  Sun  Away      L   0   1
#
#            Opponent  ...  Match Report  Notes    Sh   SoT  Dist   FK   PK  \
# 1          West Ham  ...  Match Report    NaN  13.0   1.0  18.7  1.0  1.0
# 2       Bournemouth  ...  Match Report    NaN  19.0   7.0  17.5  0.0  0.0
# 3     Newcastle Utd  ...  Match Report    NaN  21.0  10.0  16.2  1.0  0.0
# 4    Crystal Palace  ...  Match Report    NaN  18.0   5.0  14.1  0.0  0.0
# 5   Nott'ham Forest  ...  Match Report    NaN  17.0   9.0  14.8  0.0  0.0
# 6       Aston Villa  ...  Match Report    NaN  13.0   4.0  16.8  1.0  0.0
# 9            Wolves  ...  Match Report    NaN  16.0   7.0  19.4  0.0  0.0
# 10   Manchester Utd  ...  Match Report    NaN  22.0   9.0  14.2  1.0  0.0
# 12      Southampton  ...  Match Report    NaN  21.0   8.0  13.9  0.0  0.0
# 14        Liverpool  ...  Match Report    NaN  16.0   6.0  18.4  0.0  0.0
#
#    PKatt  Season             Team
# 1    1.0    2023  Manchester City
# 2    0.0    2023  Manchester City
# 3    0.0    2023  Manchester City
# 4    0.0    2023  Manchester City
# 5    0.0    2023  Manchester City
# 6    0.0    2023  Manchester City
# 9    0.0    2023  Manchester City
# 10   0.0    2023  Manchester City
# 12   0.0    2023  Manchester City
# 14   0.0    2023  Manchester City
#
# [10 rows x 27 columns]

# %%
matches["Date"] = pd.to_datetime(matches["Date"])
matches.dtypes
# Out:
# Date            datetime64[ns]
# Time                    object
# Comp                    object
# Round                   object
# Day                     object
# Venue                   object
# Result                  object
# GF                       int64
# GA                       int64
# Opponent                object
# xG                     float64
# xGA                    float64
# Poss                   float64
# Attendance             float64
# Captain                 object
# Formation               object
# Referee                 object
# Match Report            object
# Notes                  float64
# Sh                     float64
# SoT                    float64
# Dist                   float64
# FK                     float64
# PK                     float64
# PKatt                  float64
# Season                   int64
# Team                    object
# dtype: object

# %%
matches["Venue_Code"] = matches["Venue"].astype("category").cat.codes
matches["Opp_Code"] = matches["Opponent"].astype("category").cat.codes
matches["Hour"] = matches["Time"].str.replace(":.+","",regex=True).astype("int")
matches["Day_Code"] = matches["Date"].dt.day_of_week
matches["Target"] = (matches["Result"]=="W").astype("int")
matches
# Out:
#          Date   Time            Comp         Round  Day Venue Result  GF  GA  \
# 1  2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away      W   2   0
# 2  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W   4   0
# 3  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D   3   3
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W   4   2
# 5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W   6   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L   0   4
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L   0   2
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W   1   0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L   0   1
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W   1   0
#
#            Opponent  ...   FK   PK  PKatt  Season              Team  \
# 1          West Ham  ...  1.0  1.0    1.0    2023   Manchester City
# 2       Bournemouth  ...  0.0  0.0    0.0    2023   Manchester City
# 3     Newcastle Utd  ...  1.0  0.0    0.0    2023   Manchester City
# 4    Crystal Palace  ...  0.0  0.0    0.0    2023   Manchester City
# 5   Nott'ham Forest  ...  0.0  0.0    0.0    2023   Manchester City
# ..              ...  ...  ...  ...    ...     ...               ...
# 38        Tottenham  ...  0.0  0.0    0.0    2021  Sheffield United
# 39   Crystal Palace  ...  1.0  0.0    0.0    2021  Sheffield United
# 40          Everton  ...  0.0  0.0    0.0    2021  Sheffield United
# 41    Newcastle Utd  ...  1.0  0.0    0.0    2021  Sheffield United
# 42          Burnley  ...  0.0  0.0    0.0    2021  Sheffield United
#
#    Venue_Code Opp_Code Hour  Day_Code  Target
# 1           0       23   16         6       1
# 2           1        2   15         5       1
# 3           0       15   16         6       0
# 4           1        7   15         5       1
# 5           1       17   19         2       1
# ..        ...      ...  ...       ...     ...
# 38          0       20   19         6       0
# 39          1        7   15         5       0
# 40          0        8   19         6       1
# 41          0       15   18         2       0
# 42          1        5   16         6       1
#
# [2280 rows x 32 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
from sklearn.metrics import precision_score

# %%
grouped_matches = matches.groupby("Team")

# %%
def rolling_averages(group,cols,new_cols):
    group = group.sort_values("Date")
    rolling_stats = group[cols].rolling(3,closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

cols = ['GF','GA','Sh','SoT','Dist','FK','PK','PKatt']
new_cols = [f"{c}_rolling" for c in cols]

# %%
matches_rolling = grouped_matches.apply(lambda x: rolling_averages(x,cols,new_cols))
matches_rolling = matches_rolling.droplevel("Team")
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            Date   Time            Comp         Round  Day Venue Result  GF  \
# 0    2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W   2
# 1    2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L   0
# 2    2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L   0
# 3    2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W   1
# 4    2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L   0
# ...         ...    ...             ...           ...  ...   ...    ...  ..
# 2197 2023-04-29  15:00  Premier League  Matchweek 34  Sat  Away      L   0
# 2198 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W   1
# 2199 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Away      L   0
# 2200 2023-05-20  15:00  Premier League  Matchweek 37  Sat  Home      D   1
# 2201 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0
#
#       GA         Opponent  ...  Day_Code  Target  GF_rolling  GA_rolling  \
# 0      1    Sheffield Utd  ...         6       1    2.000000    1.333333
# 1      1  Manchester City  ...         5       0    1.666667    1.666667
# 2      1   Leicester City  ...         6       0    1.000000    1.666667
# 3      0   Manchester Utd  ...         6       1    0.666667    1.000000
# 4      3      Aston Villa  ...         6       0    0.333333    0.666667
# ...   ..              ...  ...       ...     ...         ...         ...
# 2197   6         Brighton  ...         5       0    1.666667    0.666667
# 2198   0      Aston Villa  ...         5       1    1.000000    2.666667
# 2199   2   Manchester Utd  ...         5       0    1.000000    2.000000
# 2200   1          Everton  ...         5       0    0.333333    2.666667
# 2201   5          Arsenal  ...         6       0    0.666667    1.000000
#
#      Sh_rolling SoT_rolling Dist_rolling FK_rolling  PK_rolling  PKatt_rolling
# 0      8.000000    3.666667    14.633333   0.666667    0.000000       0.000000
# 1      5.666667    3.666667    15.366667   0.000000    0.000000       0.000000
# 2      7.000000    3.666667    16.566667   0.666667    0.000000       0.000000
# 3      9.666667    4.000000    16.566667   1.000000    0.000000       0.000000
# 4      9.666667    2.666667    19.333333   1.000000    0.333333       0.333333
# ...         ...         ...          ...        ...         ...            ...
# 2197  11.666667    4.666667    18.700000   0.666667    0.333333       0.333333
# 2198  11.333333    2.333333    18.800000   0.666667    0.333333       0.333333
# 2199   8.000000    2.000000    17.766667   0.000000    0.333333       0.333333
# 2200   7.000000    1.333333    15.600000   0.000000    0.000000       0.000000
# 2201   8.000000    2.333333    15.333333   0.333333    0.000000       0.000000
#
# [2202 rows x 40 columns]

# %%
def make_predictions(data,predictors):
    train =data[data["Date"] < '2022-12-07']
    test = data[data["Date"] > '2022-12-07']
    rf.fit(train[predictors],train["Target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["Target"],prediction=preds),index=test.index)
    precision = precision_score(test["Target"],preds)
    return combined,precision

# %%
combined,precision = make_predictions(matches_rolling,predictors+new_cols)
combined
# Out:
#       actual  prediction
# 87         1           0
# 88         1           1
# 89         0           1
# 90         1           1
# 91         1           0
# ...      ...         ...
# 2197       0           0
# 2198       1           0
# 2199       0           0
# 2200       0           0
# 2201       0           0
#
# [468 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["Date",'Team','Opponent','Result']],left_index=True,right_index=True)
combined
# Out:
#       actual  prediction       Date                     Team        Opponent  \
# 87         1           0 2022-12-26                  Arsenal        West Ham
# 88         1           1 2022-12-31                  Arsenal        Brighton
# 89         0           1 2023-01-03                  Arsenal   Newcastle Utd
# 90         1           1 2023-01-15                  Arsenal       Tottenham
# 91         1           0 2023-01-22                  Arsenal  Manchester Utd
# ...      ...         ...        ...                      ...             ...
# 2197       0           0 2023-04-29  Wolverhampton Wanderers        Brighton
# 2198       1           0 2023-05-06  Wolverhampton Wanderers     Aston Villa
# 2199       0           0 2023-05-13  Wolverhampton Wanderers  Manchester Utd
# 2200       0           0 2023-05-20  Wolverhampton Wanderers         Everton
# 2201       0           0 2023-05-28  Wolverhampton Wanderers         Arsenal
#
#      Result
# 87        W
# 88        W
# 89        D
# 90        W
# 91        W
# ...     ...
# 2197      L
# 2198      W
# 2199      L
# 2200      D
# 2201      L
#
# [468 rows x 6 columns]

# %%
precision
# Out:
# 0.5688073394495413

# %%
class MissingDict(dict):
    __missing__ = lambda self, key:key

map_values = {
    "Brighton and Hove Albion": "Brighton",
    "Manchester United": "Manchester Utd",
    "Newcastle United": "Newcastle Utd",
    "Sheffield United": "Sheffield Utd",
    "Tottenham Hotspur": "Tottenham",
    "West Ham United": "West Ham",
    "Wolverhampton Wanderers": "Wolves",
    "Nottingham Forest": "Nott'ham Forest",
    "West Bromwich Albion": "West Brom"
}

mapping = MissingDict(**map_values)

# %%
combined["New_Team"] = combined["Team"].map(mapping)
combined
# Out:
#       actual  prediction       Date                     Team        Opponent  \
# 87         1           0 2022-12-26                  Arsenal        West Ham
# 88         1           1 2022-12-31                  Arsenal        Brighton
# 89         0           1 2023-01-03                  Arsenal   Newcastle Utd
# 90         1           1 2023-01-15                  Arsenal       Tottenham
# 91         1           0 2023-01-22                  Arsenal  Manchester Utd
# ...      ...         ...        ...                      ...             ...
# 2197       0           0 2023-04-29  Wolverhampton Wanderers        Brighton
# 2198       1           0 2023-05-06  Wolverhampton Wanderers     Aston Villa
# 2199       0           0 2023-05-13  Wolverhampton Wanderers  Manchester Utd
# 2200       0           0 2023-05-20  Wolverhampton Wanderers         Everton
# 2201       0           0 2023-05-28  Wolverhampton Wanderers         Arsenal
#
#      Result New_Team
# 87        W  Arsenal
# 88        W  Arsenal
# 89        D  Arsenal
# 90        W  Arsenal
# 91        W  Arsenal
# ...     ...      ...
# 2197      L   Wolves
# 2198      W   Wolves
# 2199      L   Wolves
# 2200      D   Wolves
# 2201      L   Wolves
#
# [468 rows x 7 columns]

# %%
merged = combined.merge(combined,left_on=["Date","New_Team"],right_on=["Date","Opponent"])
merged
# Out:
#      actual_x  prediction_x       Date                   Team_x  \
# 0           1             0 2022-12-26                  Arsenal
# 1           1             1 2022-12-31                  Arsenal
# 2           0             1 2023-01-03                  Arsenal
# 3           1             1 2023-01-15                  Arsenal
# 4           1             0 2023-01-22                  Arsenal
# ..        ...           ...        ...                      ...
# 463         0             0 2023-04-29  Wolverhampton Wanderers
# 464         1             0 2023-05-06  Wolverhampton Wanderers
# 465         0             0 2023-05-13  Wolverhampton Wanderers
# 466         0             0 2023-05-20  Wolverhampton Wanderers
# 467         0             0 2023-05-28  Wolverhampton Wanderers
#
#          Opponent_x Result_x New_Team_x  actual_y  prediction_y  \
# 0          West Ham        W    Arsenal         0             0
# 1          Brighton        W    Arsenal         0             0
# 2     Newcastle Utd        D    Arsenal         0             0
# 3         Tottenham        W    Arsenal         0             0
# 4    Manchester Utd        W    Arsenal         0             1
# ..              ...      ...        ...       ...           ...
# 463        Brighton        L     Wolves         1             1
# 464     Aston Villa        W     Wolves         0             0
# 465  Manchester Utd        L     Wolves         1             0
# 466         Everton        D     Wolves         0             1
# 467         Arsenal        L     Wolves         1             0
#
#                        Team_y Opponent_y Result_y      New_Team_y
# 0             West Ham United    Arsenal        L        West Ham
# 1    Brighton and Hove Albion    Arsenal        L        Brighton
# 2            Newcastle United    Arsenal        D   Newcastle Utd
# 3           Tottenham Hotspur    Arsenal        L       Tottenham
# 4           Manchester United    Arsenal        L  Manchester Utd
# ..                        ...        ...      ...             ...
# 463  Brighton and Hove Albion     Wolves        W        Brighton
# 464               Aston Villa     Wolves        L     Aston Villa
# 465         Manchester United     Wolves        W  Manchester Utd
# 466                   Everton     Wolves        D         Everton
# 467                   Arsenal     Wolves        W         Arsenal
#
# [468 rows x 13 columns]

# %%
merged[(merged["prediction_x"]==1) & (merged["prediction_y"]==0)]["actual_x"].value_counts()
# Out:
# 1    58
# 0    41
# Name: actual_x, dtype: int64

# %%
Precision = 58/(58+41)
Precision
# Out:
# 0.5858585858585859
